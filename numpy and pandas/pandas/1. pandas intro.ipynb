# %%
import pandas as pd

# %% [markdown]
# Files :
#     sample csv file - https://github.com/codeforamerica/ohana-api/tree/master/data/sample-csv
#     Titanic - https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
#     excel file - https://github.com/finbourne/sample-excel

# %%
address_df = pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv')
address_df.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
a = 1
type(a)
# Out:
# int

# %%
type(address_df)
# Out:
# pandas.core.frame.DataFrame

# %%
address_df.shape # rows and columns
# Out:
# (21, 8)

# %%
address_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              21 non-null     int64
#  1   location_id     21 non-null     int64
#  2   address_1       21 non-null     object
#  3   address_2       2 non-null      object
#  4   city            21 non-null     object
#  5   state_province  21 non-null     object
#  6   postal_code     21 non-null     object
#  7   country         21 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 1.4+ KB

# %%
address_df.dtypes
# Out:
# id                 int64
# location_id        int64
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
address_df.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
# pd.read_csv('sample_test.csv',sep='|' , skiprows=[1,3])

# %%
# df1 = pd.read_csv('sample_test.csv',sep='|' , skiprows=[1,3])

# %%
df = address_df

# %%
df.dtypes
# Out:
# id                 int64
# location_id        int64
# address_1         object
# address_2         object
# city              object
# state_province    object
# postal_code       object
# country           object
# dtype: object

# %%
df.head(2) # to get top 2 values, normally head() return first 5 values. we can customize it by passing a value.
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US

# %%
df.tail(3) # to get last 3 values
# Out:
#     id  location_id                   address_1  address_2           city  \
# 18  19           19         19 West 39th Avenue        NaN      San Mateo
# 19  20           21          123 El Camino Real        NaN        Belmont
# 20  21           22  2013 Avenue of the fellows  Suite 100  San Francisco
#
#    state_province postal_code country
# 18             CA       94403      US
# 19             CA       94002      US
# 20             CA       94103      US

# %%
a = df["city"]
type(a)

# %%
df1 = df[["id" ,'location_id','city' ]]

# %%
type(df1)
df1.set_index('id') # setting the index
# Out:
#     location_id                 city
# id
# 1             1         Redwood City
# 2             2            San Mateo
# 3             3            San Mateo
# 4             4            San Mateo
# 5             5            San Mateo
# 6             6           Menlo Park
# 7             7           Menlo Park
# 8             8           Menlo Park
# 9             9         Redwood City
# 10           10         Redwood City
# 11           11         Redwood City
# 12           12         Redwood City
# 13           13         Redwood City
# 14           14         Redwood City
# 15           15        San Francisco
# 16           16            Sunnyvale
# 17           17  South San Francisco
# 18           18         Redwood City
# 19           19            San Mateo
# 20           21              Belmont
# 21           22        San Francisco

# %%
type(df[['city']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.sort_index(axis=1) # sorting the columns
# Out:
#                      address_1  address_2                 city country  id  \
# 0        2600 Middlefield Road        NaN         Redwood City      US   1
# 1             24 Second Avenue        NaN            San Mateo      US   2
# 2             24 Second Avenue        NaN            San Mateo      US   3
# 3             24 Second Avenue        NaN            San Mateo      US   4
# 4             24 Second Avenue        NaN            San Mateo      US   5
# 5            800 Middle Avenue        NaN           Menlo Park      US   6
# 6               500 Arbor Road        NaN           Menlo Park      US   7
# 7            800 Middle Avenue        NaN           Menlo Park      US   8
# 8        2510 Middlefield Road        NaN         Redwood City      US   9
# 9        1044 Middlefield Road        NaN         Redwood City      US  10
# 10         2140 Euclid Avenue.        NaN         Redwood City      US  11
# ...

# %%
df
# Out:
#                      address_1  address_2                 city country  id  \
# 0        2600 Middlefield Road        NaN         Redwood City      US   1
# 1             24 Second Avenue        NaN            San Mateo      US   2
# 2             24 Second Avenue        NaN            San Mateo      US   3
# 3             24 Second Avenue        NaN            San Mateo      US   4
# 4             24 Second Avenue        NaN            San Mateo      US   5
# 5            800 Middle Avenue        NaN           Menlo Park      US   6
# 6               500 Arbor Road        NaN           Menlo Park      US   7
# 7            800 Middle Avenue        NaN           Menlo Park      US   8
# 8        2510 Middlefield Road        NaN         Redwood City      US   9
# 9        1044 Middlefield Road        NaN         Redwood City      US  10
# 10         2140 Euclid Avenue.        NaN         Redwood City      US  11
# ...

# %%
# pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name = "Allocations") ; excel has to be read in this way

# %%
df.keys() # returns a list of columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')
