# %%
import pandas as pd

# %%
df = pd.read_csv('../data/survey_results_public.csv') 
# reading the data from csv file using read_csv(path='')

# %%
df.shape # returns no.of rows and columns in tuple format.
# shape is attribute in dataframe, which gives info of no.of rows and colums
# Out:
# (73268, 79)

# %%
pd.set_option('display.max_columns', 85)

# %%
schema_df = pd.read_csv('../data/survey_results_schema.csv')

# %%
pd.set_option('display.max_rows', 90)
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# ...

# %%
schema_df.head(7) 
# returns first 5 rows of dataframe, we can pass int value to display no.of
# Out:
#       qid             qname  \
# 0   QID16                S0
# 1   QID12          MetaInfo
# 2    QID1                S1
# 3    QID2        MainBranch
# 4  QID296        Employment
# 5  QID308        RemoteWork
# 6  QID297  CodingActivities
#
#                                             question force_resp  type selector
# 0  <div><span style="font-size:19px;"><strong>Hel...      False    DB       TB
# 1                                  Browser Meta Info      False  Meta  Browser
# 2  <span style="font-size:22px; font-family: aria...      False    DB       TB
# 3  Which of the following options best describes ...       True    MC     SAVR
# 4  Which of the following best describes your cur...      False    MC     MAVR
# 5  Which best describes your current work situation?      False    MC     SAVR
# 6  Which of the following best describes the code...      False    MC     MAVR

# %%
schema_df.tail(9) 
# returns last 5 rows of dataframe, same int can be passed here
# Out:
#        qid        qname                                           question  \
# 70  QID289  Knowledge_5  I know which system or resource to use to find...
# 71  QID289  Knowledge_6  I often find myself answering questions that I...
# 72  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 73  QID290  Frequency_1  Needing help from people outside of your immed...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp type selector
# 70        NaN   MC     MAVR
# 71        NaN   MC     MAVR
# 72        NaN   MC     MAVR
# 73        NaN   MC     MAVR
# 74        NaN   MC     MAVR
# 75        NaN   MC     MAVR
# ...

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df['MainBranch']
# Out:
# 0                                            None of these
# 1                           I am a developer by profession
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 73263                       I am a developer by profession
# 73264                       I am a developer by profession
# 73265    I am not primarily a developer, but I write co...
# 73266                       I am a developer by profession
# 73267    I used to be a developer by profession, but no...
# Name: MainBranch, Length: 73268, dtype: object

# %%
df.get('MainBranch')
# Out:
# 0                                            None of these
# 1                           I am a developer by profession
# 2        I am not primarily a developer, but I write co...
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 73263                       I am a developer by profession
# 73264                       I am a developer by profession
# 73265    I am not primarily a developer, but I write co...
# 73266                       I am a developer by profession
# 73267    I used to be a developer by profession, but no...
# Name: MainBranch, Length: 73268, dtype: object

# %%
people = {
    'first': ['Sivakuamr', 'Moksha', 'Lakshmi'],
    'last' : ['Revanuru', 'Sree', 'Veerapu'],
    'email': ['siva@gmail.com', 'moksh23@gmail.com', 'lucky@gmail.com']
}

# %%
people['email']
# Out:
# ['siva@gmail.com', 'moksh23@gmail.com', 'lucky@gmail.com']

# %%
# converting python dict obj to pandas dataframe.
pp = pd.DataFrame(people)

# %%
pp
# Out:
#        first      last              email
# 0  Sivakuamr  Revanuru     siva@gmail.com
# 1     Moksha      Sree  moksh23@gmail.com
# 2    Lakshmi   Veerapu    lucky@gmail.com

# %%
s = pp.get('first', default = 1)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s[0]
# Out:
# 'Sivakuamr'

# %%
pp.first
# Out:
# <bound method NDFrame.first of        first      last              email
# 0  Sivakuamr  Revanuru     siva@gmail.com
# 1     Moksha      Sree  moksh23@gmail.com
# 2    Lakshmi   Veerapu    lucky@gmail.com>

# %%
pp[['first', 'email']]
# Out:
#        first              email
# 0  Sivakuamr     siva@gmail.com
# 1     Moksha  moksh23@gmail.com
# 2    Lakshmi    lucky@gmail.com

# %%
pp.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[1] # first row
# Out:
# ResponseId                                                                        2
# MainBranch                                           I am a developer by profession
# Employment                                                      Employed, full-time
# RemoteWork                                                             Fully remote
# CodingActivities                           Hobby;Contribute to open-source projects
# EdLevel                                                                         NaN
# LearnCode                                                                       NaN
# LearnCodeOnline                                                                 NaN
# LearnCodeCoursesCert                                                            NaN
# YearsCode                                                                       NaN
# YearsCodePro                                                                    NaN
# ...

# %%
df.iloc[[0,1]] #rows
# Out:
#    ResponseId                      MainBranch           Employment  \
# 0           1                   None of these                  NaN
# 1           2  I am a developer by profession  Employed, full-time
#
#      RemoteWork                          CodingActivities EdLevel LearnCode  \
# 0           NaN                                       NaN     NaN       NaN
# 1  Fully remote  Hobby;Contribute to open-source projects     NaN       NaN
#
#   LearnCodeOnline LearnCodeCoursesCert YearsCode YearsCodePro DevType OrgSize  \
# 0             NaN                  NaN       NaN          NaN     NaN     NaN
# 1             NaN                  NaN       NaN          NaN     NaN     NaN
#
#   PurchaseInfluence BuyNewTool Country              Currency  CompTotal  \
# 0               NaN        NaN     NaN                   NaN        NaN
# 1               NaN        NaN  Canada  CAD\tCanadian dollar        NaN
#
#   CompFreq LanguageHaveWorkedWith LanguageWantToWorkWith  \
# ...

# %%
schema_df.loc[[0,4]]
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 4  QID296  Employment  Which of the following best describes your cur...
#
#   force_resp type selector
# 0      False   DB       TB
# 4      False   MC     MAVR

# %%
schema_df.loc[[0,4], 'type']
# Out:
# 0    DB
# 4    MC
# Name: type, dtype: object

# %%
schema_df.loc[[0,4,6,7], ['qid', 'qname', 'selector']]
# it prints 0,4,6,7 rows data of qid, qname, selector column.
# Out:
#       qid             qname selector
# 0   QID16                S0       TB
# 4  QID296        Employment     MAVR
# 6  QID297  CodingActivities     MAVR
# 7  QID190                S2       TB

# %%
cols = schema_df.columns
print(type(cols))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
df['RemoteWork'].value_counts()
# Out:
# Fully remote                            25341
# Hybrid (some remote, some in-person)    25021
# Full in-person                           8596
# Name: RemoteWork, dtype: int64
